# %% [markdown]
# # GAN

# %%
train_data = 'https://www.qminitiative.org/UserFiles/files/ref_phase2_train_x.csv'
train_label = 'https://www.qminitiative.org/UserFiles/files/ref_phase2_train_y.csv'
valid_data = 'https://www.qminitiative.org/UserFiles/files/ref_phase2_valid_x.csv'

# %%
import pandas as pd

# %%
train_data = pd.read_csv(train_data)
train_labels = pd.read_csv(train_label, header=None)
valid_data = pd.read_csv(valid_data)
